# %% [markdown]
# ## LAST_FM

# %%
from dotenv import load_dotenv
import os

import time
import re

import pandas as pd
import requests

# %%
LASTFM_API_KEY = os.getenv("LASTFM_API_KEY")
LASTFM_SECRET_KEY = os.getenv("LASTFM_SECRET_KEY")

# %%
def get_artist_info(artist_name):  # Generamos una función para obtener info de la API de LastFM
    API_KEY = LASTFM_API_KEY
    BASE_URL = "https://ws.audioscrobbler.com/2.0/"  # Conexión a la API de LastFM

    params = {
        "method": "artist.getinfo",
        "artist": artist_name,
        "api_key": API_KEY,
        "format": "json",
        "autocorrect": 1,
        "lang": "en"
    }

    response = requests.get(BASE_URL, params=params, timeout=30)

    # Si la respuesta HTTP no es correcta, se salta este artista
    if response.status_code != 200:
        print(f"❌ HTTP {response.status_code} para el artista: {artist_name}")
        return None

    # Intentar convertir la respuesta a JSON (a veces la API devuelve HTML o vacío)
    try:
        data = response.json()
    except ValueError:
        print(f"❌ Respuesta no JSON para el artista: {artist_name} | Primeros caracteres: {response.text[:120]}")
        return None

    # La API de LastFM puede devolver errores dentro del JSON
    if isinstance(data, dict) and "error" in data:
        print(f"❌ Error de la API LastFM: {data.get('message')}")
        return None

    artist = data["artist"]
    listeners = artist["stats"]["listeners"]
    playcount = artist["stats"]["playcount"]
    similar_artists = [a["name"] for a in artist["similar"]["artist"]]
    similar_artist = similar_artists[0] if similar_artists else None

    # Información biográfica del artista
    bio = data.get("artist", {}).get("bio", {})
    summary = bio.get("summary", {})

    return {
        "artist_name": artist["name"],
        "biography": summary,
        "listeners": listeners,
        "playcount": playcount,
        "similar_artist": similar_artist
    }

# %%
# Incluir aquí el CSV de los datos de Spotify
df_spotify = pd.read_csv("canciones-spotify.csv")  # Transformación en DataFrame
df_spotify.head()
# Out:
#                        id             track_name  \
# 0  0LpHC9mhPAQC98IjXZIrif   The Election of 1800
# 1  6oF8ueLn5hIl4PRp17sxW6   That Would Be Enough
# 2  4eeN8erNIbW2osT0knz5vT             I Know Him
# 3  3lXyAQ0kekAvY5LodpWmUs  Ten Duel Commandments
# 4  1llkMtLL4vbe0pr3NV2ckg            Let Me Hear
#
#                        artist_name  year       genre album_type release_date  \
# 0                     Daveed Diggs  2015  soundtrack      album   2015-09-25
# 1                     Phillipa Soo  2015  soundtrack      album   2015-09-25
# 2                   Jonathan Groff  2015  soundtrack      album   2015-09-25
# 3               Lin-Manuel Miranda  2015  soundtrack      album   2015-09-25
# 4  Fear, and Loathing in Las Vegas  2015  soundtrack      album   2015-09-30
#
#    popularity
# 0          65
# 1          66
# 2          65
# 3          67
# 4          59

# %%
df_spotify['artist_name'].tolist() # Creación de lista de artistas para ejecutar en archivo "artistas_LastFM.ipynb"
# Out:
# ['Daveed Diggs',
#  'Phillipa Soo',
#  'Jonathan Groff',
#  'Lin-Manuel Miranda',
#  'Fear, and Loathing in Las Vegas',
#  'Kazuya Yoshii',
#  'Lin-Manuel Miranda',
#  'Leslie Odom Jr.',
#  'Phillipa Soo',
#  'Original Broadway Cast of Hamilton',
#  'Daveed Diggs',
#  'Aimer',
#  'Lin-Manuel Miranda',
#  'Leslie Odom Jr.',
#  'Christopher Jackson',
#  'Toby Fox',
#  'Toby Fox',
#  'Leslie Odom Jr.',
#  'KANA-BOON',
#  'Okieriete Onaodowan',
#  'Leslie Odom Jr.',
#  'Leslie Odom Jr.',
#  'Michael Giacchino',
#  'Toby Fox',
#  'Goose house',
#  'Toby Fox',
#  'Toby Fox',
#  'Toby Fox',
#  'Phillipa Soo',
#  'Jasmine Cephas-Jones',
#  'Renée Elise Goldsberry',
#  'Jonathan Groff',
#  'Toby Fox',
#  'Marcin Przybyłowicz',
#  'Mikolai Stroinski',
#  'Original Broadway Cast of Hamilton',
#  'Leslie Odom Jr.',
#  'Lin-Manuel Miranda',
#  'Lin-Manuel Miranda',
#  'Jonathan Groff',
#  'Thayne Jasperson',
#  'Renée Elise Goldsberry',
#  'Leslie Odom Jr.',
#  'Phillipa Soo',
#  'John Williams',
#  'Lin-Manuel Miranda',
#  'Toby Fox',
#  'Toby Fox',
#  'Leslie Odom Jr.',
#  'Toby Fox',
#  'Toby Fox',
#  'Yutaka Yamada',
#  'Phillipa Soo',
#  'Lin-Manuel Miranda',
#  'The Barden Bellas',
#  'Patrick Doyle',
#  'Renée Elise Goldsberry',
#  'Toby Fox',
#  'Leslie Odom Jr.',
#  'Toby Fox',
#  'Michael Giacchino',
#  'Eir Aoi',
#  'Christopher Jackson',
#  'Original Broadway Cast of Hamilton',
#  'Christopher Jackson',
#  'Leslie Odom Jr.',
#  'Original Broadway Cast of Hamilton',
#  'Marcin Przybyłowicz',
#  'Toby Fox',
#  'Toby Fox',
#  'Toby Fox',
#  'Lin-Manuel Miranda',
#  'Phillipa Soo',
#  'Dario Marianelli',
#  'Original Broadway Cast of Hamilton',
#  'Toby Fox',
#  'Konomi Suzuki',
#  'Mikolai Stroinski',
#  'Marcin Przybyłowicz',
#  'Toby Fox',
#  'Ryuichi Sakamoto',
#  'Trevor Morris',
#  'John Williams',
#  'Christopher Jackson',
#  'Basil Poledouris',
#  'Toby Fox',
#  'Toby Fox',
#  'Agrupacion Musical Nuestro Padre Jesús Despojado de Jaen',
#  'Toby Fox',
#  'Toby Fox',
#  'Toby Fox',
#  'Toby Fox',
#  'Toby Fox',
#  'Roque Baños',
#  'Lin-Manuel Miranda',
#  'Toby Fox',
#  'Film Symphony Orchestra',
#  'Toby Fox',
#  'BRADIO',
#  'Bear McCreary',
#  'Sho Oosawa',
#  'TK from Ling tosite sigure',
#  'SIE Sound Team',
#  'Percival Schuttenbach',
#  'Inon Zur',
#  'James Newton Howard',
#  'Harry Gregson-Williams',
#  'Toby Fox',
#  'Toby Fox',
#  'Toby Fox',
#  'Toby Fox',
#  'SIE Sound Team',
#  'Toby Fox',
#  'Alan Silvestri',
#  'Toby Fox',
#  'GENERATIONS from EXILE TRIBE',
#  'Peter Gregson',
#  'Toby Fox',
#  'John Williams',
#  'Film Symphony Orchestra',
#  'Toby Fox',
#  'SIE Sound Team',
#  'Toby Fox',
#  'Toby Fox',
#  'Patrick Doyle',
#  'Bear McCreary',
#  'Toby Fox',
#  'Mikolai Stroinski',
#  'Toby Fox',
#  'Patrick Doyle',
#  'Bear McCreary',
#  'Aqua Timez',
#  'Marcin Przybyłowicz',
#  'Toby Fox',
#  'Big Giant Circles',
#  'Dario Marianelli',
#  'Toby Fox',
#  'Mikolai Stroinski',
#  'Marcin Przybyłowicz',
#  'Patrick Doyle',
#  'LiSA',
#  'Ramin Djawadi',
#  'Toby Fox',
#  'Ariana DeBose',
#  'Bear McCreary',
#  'Toby Fox',
#  'Toby Fox',
#  'Toby Fox',
#  'Gareth Coker',
#  'Das Sound Machine',
#  'Ramin Djawadi',
#  'MAN WITH A MISSION',
#  'Yugo Kanno',
#  'Kyle Dixon & Michael Stein',
#  'MOB CHOIR',
#  'Yuki Hayashi',
#  'THE ORAL CIGARETTES',
#  'La La Land Cast',
#  'Ben Platt',
#  'Ramin Djawadi',
#  'James Newton Howard',
#  'Ryan Gosling',
#  'Robert D.',
#  'ConcernedApe',
#  'Yuki Hayashi',
#  'Fernando Velázquez',
#  'Yuki Hayashi',
#  'Kyle Dixon & Michael Stein',
#  'Yoko Shimomura',
#  'Christopher Fitzgerald',
#  'Justin Hurwitz',
#  'Max Richter',
#  'Hans Zimmer',
#  'batta',
#  'Ramin Djawadi',
#  'Kyle Dixon & Michael Stein',
#  'John Legend',
#  'Ryan Gosling',
#  'Kyle Dixon & Michael Stein',
#  'Piotr Musiał',
#  'BURNOUT SYNDROMES',
#  'Emma Stone',
#  '3年E組うた担(渚&茅野&業&磯貝&前原)',
#  'Rupert Gregson-Williams',
#  'Abel Korzeniowski',
#  'Ramin Djawadi',
#  'Emma Stone',
#  'Justin Hurwitz',
#  'Fernando Velázquez',
#  'Fernando Velázquez',
#  'Film Symphony Orchestra',
#  'Yuki Hayashi',
#  'RADWIMPS',
#  'Kyle Dixon & Michael Stein',
#  'BURNOUT SYNDROMES',
#  'Ramin Djawadi',
#  'Ryan Gosling',
#  'Kyle Dixon & Michael Stein',
#  'Ryan Gosling',
#  'JAM Project',
#  'Shiro SAGISU',
#  'Yugo Kanno',
#  '7!!',
#  'GUMMY',
#  'YOON MIRAE',
#  'Geek Music',
#  'Adrian Barba',
#  'Kimiko Glenn',
#  'Aests',
#  'Robert D.',
#  'Adrian Barba',
#  'Kyle Dixon & Michael Stein',
#  'Hans Zimmer',
#  'Fernando Velázquez',
#  'Ramin Djawadi',
#  'Kyle Dixon & Michael Stein',
#  'Chris Remo',
#  'Kyle Dixon & Michael Stein',
#  'Marcin Przybyłowicz',
#  'Piotr Musiał',
#  'Ramin Djawadi',
#  'Kyle Dixon & Michael Stein',
#  'SID',
#  'Mikolai Stroinski',
#  '梶浦 由記',
#  'Rupert Gregson-Williams',
#  'Christopher Tin',
#  'Haruka Tomatsu',
#  'kensuke ushio',
#  'Hans Zimmer',
#  'Henry Jackman',
#  'Ramin Djawadi',
#  'The Meridian Studio Ensemble',
#  'Kyle Dixon & Michael Stein',
#  'Yoko Shimomura',
#  'Rupert Gregson-Williams',
#  '3年E組うた担(渚&茅野&業&磯貝&前原)',
#  'James Newton Howard',
#  'Piotr Musiał',
#  'Kyle Dixon & Michael Stein',
#  'Kyle Dixon & Michael Stein',
#  'Tina Guo',
#  'Ramin Djawadi',
#  'James Newton Howard',
#  'Fernando Velázquez',
#  'Fernando Velázquez',
#  'batta',
#  'Rupert Gregson-Williams',
#  'Hans Zimmer',
#  'Yuki Hayashi',
#  'YOON MIRAE',
#  'Jessie Mueller',
#  'Pritam',
#  'Ramin Djawadi',
#  'K.Will',
#  'LeeHi',
#  'Ramin Djawadi',
#  'NICO Touches the Walls',
#  'Arijit Singh',
#  '梶浦 由記',
#  'Michael Giacchino',
#  'Kyle Dixon & Michael Stein',
#  'Jessie Mueller',
#  'Rupert Gregson-Williams',
#  'Weaver',
#  'Brian Tyler',
#  'Hans Zimmer',
#  'Yoko Shimomura',
#  'Ramin Djawadi',
#  'Chris Remo',
#  'CHEN',
#  'Christopher Tin',
#  'SPYAIR',
#  'Marcin Przybyłowicz',
#  'Nightmargin',
#  'Christian Borle',
#  'Sam Kim',
#  'Michael Giacchino',
#  'Hans Zimmer',
#  'Max Richter',
#  'エミリア(CV:高橋李依)',
#  'Chris Remo',
#  'Rupert Gregson-Williams',
#  'Yugo Kanno',
#  'Piotr Musiał',
#  'Percival Schuttenbach',
#  'Justin Hurwitz',
#  'Henry Jackman',
#  'amazarashi',
#  'Amamiya Sora',
#  'Johan Söderqvist',
#  'Ramin Djawadi',
#  'Michael Giacchino',
#  'Ramin Djawadi',
#  'Kyle Dixon & Michael Stein',
#  'Kyle Dixon & Michael Stein',
#  'Henry Jackman',
#  'Ramin Djawadi',
#  'Marcin Przybyłowicz',
#  'Paolo Buonvino',
#  'Ben Platt',
#  'Loren Allred',
#  'Ziv Zaifman',
#  'Lyn',
#  'Kiyoshi Hikawa',
#  'Sawano Hiroyuki',
#  'Mike Faist',
#  'Sawano Hiroyuki',
#  'Animelmack',
#  'Lyn',
#  'Hans Zimmer',
#  'Linked Horizon',
#  'Sawano Hiroyuki',
#  'Keala Settle',
#  'Lyn',
#  'Lyn',
#  'Zac Efron',
#  'Christopher Larkin',
#  'Sawano Hiroyuki',
#  'Kesha',
#  'Ben Platt',
#  'Linked Horizon',
#  'Sawano Hiroyuki',
#  'Kyle Dixon & Michael Stein',
#  'Hugh Jackman',
#  'Michelle Williams',
#  'amazarashi',
#  'Ramin Djawadi',
#  'PornoGraffitti',
#  'Christopher Larkin',
#  'Christopher Larkin',
#  'Lyn',
#  'Hugh Jackman',
#  'Christy Altomare',
#  'Hugh Jackman',
#  'Christopher Larkin',
#  'Ramin Djawadi',
#  'Kenshi Yonezu',
#  'Hans Zimmer',
#  'D-51',
#  'Christopher Larkin',
#  'Linked Horizon',
#  'Linked Horizon',
#  'Austyn Johnson',
#  'Loren Allred',
#  'Hugh Jackman',
#  'Hugh Jackman',
#  'Kyle Dixon & Michael Stein',
#  'Keala Settle',
#  'Zac Efron',
#  'Laura Dreyfuss',
#  'Rachel Bay Jones',
#  'Rachel Bay Jones',
#  'Ben Platt',
#  'Ben Platt',
#  'Lyn',
#  'Sawano Hiroyuki',
#  'Miura Jam',
#  'Lyn',
#  'The New Barden Bellas',
#  'Yuki Hayashi',
#  'Hans Zimmer',
#  'NateWantsToBattle',
#  'Yasuharu Takanashi',
#  'MIYAVI',
#  'Tia',
#  'Christopher Larkin',
#  'Christopher Larkin',
#  'Valve Studio Orchestra',
#  'Christopher Larkin',
#  'Hans Zimmer',
#  'MYTH & ROID',
#  'Christopher Larkin',
#  'Christopher Larkin',
#  'Daniel Pemberton',
#  'Benjamin Wallfisch',
#  'Christopher Larkin',
#  'Rupert Gregson-Williams',
#  'Christopher Larkin',
#  'Christopher Larkin',
#  'La Sentencia',
#  'La Sentencia',
#  'Christopher Larkin',
#  'Steve Jablonsky',
#  'Christopher Larkin',
#  'Konomi Suzuki',
#  'Christopher Larkin',
#  'Christopher Larkin',
#  'Angelo Badalamenti',
#  'Hans Zimmer',
#  'Steve Jablonsky',
#  'Hans Zimmer',
#  'Lyn',
#  'Steve Jablonsky',
#  'Christopher Larkin',
#  'Christopher Larkin',
#  'Christopher Larkin',
#  'Ramin Djawadi',
#  'MYTH & ROID',
#  'Kyle Dixon & Michael Stein',
#  'Charlie Clouser',
#  'Nostalghia',
#  'Bear McCreary',
#  'GUMI',
#  'The Bellas',
#  'Anly',
#  'Heize',
#  'Kyle Dixon & Michael Stein',
#  'Kevin Penkin',
#  'Vasaria Project',
#  'Sam Lee',
#  'Christopher Larkin',
#  'Hans Zimmer',
#  'Mike Faist',
#  'JUNNA',
#  'Agrupación Musical Lágrimas de Dolores',
#  'アトラスサウンドチーム',
#  'Christy Altomare',
#  'Lyn',
#  'Christopher Larkin',
#  'Sawano Hiroyuki',
#  'cinema staff',
#  'Kyle Dixon & Michael Stein',
#  'Yuki Hayashi',
#  'Daniel Pemberton',
#  'Angelo Badalamenti',
#  'Joris de Man',
#  'Christopher Larkin',
#  'Kyle Dixon & Michael Stein',
#  'Kyle Dixon & Michael Stein',
#  'アトラスサウンドチーム',
#  '岡部啓一',
#  'LiSA',
#  'Christopher Larkin',
#  'Laura Dreyfuss',
#  'HENRY',
#  'Hans Zimmer',
#  'Hans Zimmer',
#  'Christopher Larkin',
#  'Sarah Schachner',
#  'アトラスサウンドチーム',
#  'X-Ray Dog',
#  'MYTH & ROID',
#  'Kyle Dixon & Michael Stein',
#  'Thomas Newman',
#  'Kyle Dixon & Michael Stein',
#  'Konomi Suzuki',
#  'Ramin Djawadi',
#  'The Bellas',
#  'LiSA',
#  'SIX',
#  'Toby Fox',
#  'Aaron Montalvo',
#  'SIX',
#  'Yoko Takahashi',
#  'YOSHIKI',
#  'Lily James',
#  'Toby Fox',
#  'Cher',
#  'Ramin Djawadi',
#  'Lily James',
#  'Hugh Skinner',
#  'Hugh Skinner',
#  'YOSHIKI',
#  'Linked Horizon',
#  'Josh Dylan',
#  'SIX',
#  'Amanda Seyfried',
#  'Yugo Kanno',
#  'KANKAKU PIERO',
#  'VK Blanka',
#  '桜島麻衣(CV:瀬戸麻沙美)',
#  'Jeremy Irvine',
#  'Lily James',
#  'Amanda Seyfried',
#  'Kelly Clarkson',
#  'みゆな',
#  'VK Blanka',
#  'Christine Baranski',
#  'Amanda Seyfried',
#  'Bear McCreary',
#  'MYTH & ROID',
#  'Yugo Kanno',
#  'ASIAN KUNG-FU GENERATION',
#  'Lily James',
#  'TK from Ling tosite sigure',
#  'Brian Tyler',
#  '遠野高志',
#  'SID',
#  'LiSA',
#  'UVERworld',
#  'Lenny code fiction',
#  'James Newton Howard',
#  'Cher',
#  '物語シリーズ',
#  'Colin Firth',
#  'Trevor Jones',
#  'Toby Fox',
#  'Creepy Nuts',
#  'LiSA',
#  'Ben Platt',
#  'SIX',
#  'Friedrich Habetler',
#  'Taylor Louderman',
#  'Toby Fox',
#  'SIX',
#  'Geek Music',
#  'Ari Afsar',
#  'SIX',
#  '桜島麻衣(CV:瀬戸麻沙美)',
#  'Christopher Larkin',
#  'Varian',
#  'SIX',
#  'Kelly Clarkson',
#  'Berlinist',
#  'Geoff Zanelli',
#  'Justin Hurwitz',
#  'Daichi Miura',
#  'Survive Said The Prophet',
#  'いとうかなこ',
#  'OxT',
#  '藤田真由美',
#  'Toby Fox',
#  'Evan Call',
#  'Friedrich Habetler',
#  'Borislav Slavov',
#  'Geoff Zanelli',
#  'Bear McCreary',
#  'Sara Bareilles',
#  'Craig David',
#  'Cher',
#  'Kesha',
#  'Lily James',
#  'Lily James',
#  'Film Symphony Orchestra',
#  'Evan Call',
#  'Toby Fox',
#  'Toby Fox',
#  'BiSH',
#  'Pentatonix',
#  'Toby Fox',
#  'Willow Sage Hart',
#  'ムービー・サウンズ・アンリミテッド',
#  'Justin Hurwitz',
#  'Justin Hurwitz',
#  'Christopher Larkin',
#  'Kumi Koda',
#  'Zac Brown Band',
#  'Olly Alexander (Years & Years)',
#  'MAX',
#  'SIX',
#  'Friedrich Habetler',
#  'Neha Kakkar',
#  'Akano',
#  'Taylor Louderman',
#  'Geek Music',
#  'Grey Henson',
#  'Brian Tyler',
#  'Justin Hurwitz',
#  'Barrett Wilbert Weed',
#  'Christopher Larkin',
#  'Toby Fox',
#  'John Williams',
#  'Toby Fox',
#  'Toby Fox',
#  'Federico Dubbini',
#  'Alan Silvestri',
#  'Cast',
#  'Kate Rockwell',
#  'ZAQ',
#  'Meryl Streep',
#  'JEONG SEWOON',
#  'Panos Mouzourakis',
#  'FLOW',
#  'Christopher Larkin',
#  'FLOW',
#  'Friedrich Habetler',
#  'Linked Horizon',
#  'FLOW',
#  'Justin Hurwitz',
#  'Hans Zimmer',
#  'Mili',
#  'Toby Fox',
#  'SIX',
#  'Toby Fox',
#  'John Paesano',
#  'UVERworld',
#  'Lena Raine',
#  'Hans Zimmer',
#  'Bradley Cooper',
#  'Lily James',
#  'The Flight',
#  'Toby Fox',
#  'Toby Fox',
#  'Christopher Larkin',
#  'Berioska',
#  'Toby Fox',
#  'vegeta',
#  'Dan Romer',
#  'Daniel Pemberton',
#  'Hans Zimmer',
#  '須田景凪',
#  'Kyle Dixon & Michael Stein',
#  'sumika',
#  'Vishal-Shekhar',
#  'Ramin Djawadi',
#  'André De Shields',
#  'Yugo Kanno',
#  'MOB CHOIR',
#  'Jamie Muscato',
#  'Hans Zimmer',
#  'Nicholas Britell',
#  'Cö shu Nie',
#  'Casey Edwards',
#  'ALI',
#  'Andrew Prahlow',
#  'Survive Said The Prophet',
#  'Ludwig Göransson',
#  'Kyle Dixon & Michael Stein',
#  '美波',
#  'Hans Zimmer',
#  'LiSA',
#  'Ramin Djawadi',
#  'Ramin Djawadi',
#  'Taron Egerton',
#  'Mrs. GREEN APPLE',
#  'Sawano Hiroyuki',
#  'UVERworld',
#  'Ramin Djawadi',
#  'QUEEN BEE',
#  'James Newton Howard',
#  'MAN WITH A MISSION',
#  'Trevor Morris',
#  'Andrew Prahlow',
#  'UVERworld',
#  'Seiko Oomori',
#  'Ramin Djawadi',
#  'Kyle Dixon & Michael Stein',
#  '中野家の五つ子',
#  'Andrew Prahlow',
#  'Akano',
#  'Thomas Newman',
#  'Alan Silvestri',
#  'ALI',
#  'Max Richter',
#  'Linked Horizon',
#  'Linked Horizon',
#  'Andrew Prahlow',
#  'Mrs. GREEN APPLE',
#  '高橋\u3000洋子',
#  'Reeve Carney',
#  "T'Shan Williams",
#  'Eva Noblezada',
#  'Trevor Morris',
#  '小畑貴裕',
#  'Alex Brightman',
#  'YOON MIRAE',
#  'Sophia Anne Caruso',
#  'Alex Brightman',
#  'Tricker',
#  'Ricky Rojas',
#  'Steven Universe',
#  'Akano',
#  'Masayuki Suzuki',
#  'André De Shields',
#  'André De Shields',
#  'Mika Nakashima',
#  'Carrie Hope Fletcher',
#  'Alex Brightman',
#  'Andrew Prahlow',
#  'Ramin Djawadi',
#  'Alan Silvestri',
#  'John Powell',
#  'the peggies',
#  'Reeve Carney',
#  'Kyle Dixon & Michael Stein',
#  'Andrew Prahlow',
#  'EMPiRE',
#  'KANKAKU PIERO',
#  'Ramin Djawadi',
#  'Hans Zimmer',
#  'Eva Noblezada',
#  'Kyle Dixon & Michael Stein',
#  'Hiroshi Kitadani',
#  'ASCA',
#  'Max Richter',
#  'Sawano Hiroyuki',
#  'Hans Zimmer',
#  'LiSA',
#  'Steven Price',
#  'Andrew Prahlow',
#  'Hans Zimmer',
#  'Yugo Kanno',
#  'Hans Zimmer',
#  'Andrew Prahlow',
#  'Hildur Guðnadóttir',
#  'MADKID',
#  'Ramin Djawadi',
#  'Andrew Prahlow',
#  'Thomas Newman',
#  'Hadestown Original Broadway Company',
#  'Heize',
#  'Hans Zimmer',
#  'Pawel Blaszczak',
#  'King Gnu',
#  'Danny Burstein',
#  'Geek Music',
#  'Creepy Nuts',
#  'Aaron Tveit',
#  'Alan Silvestri',
#  'Kyle Dixon & Michael Stein',
#  'Kyle Dixon & Michael Stein',
#  'Hadestown Original Broadway Company',
#  'Kyle Dixon & Michael Stein',
#  'Alexandre Desplat',
#  'Hans Zimmer',
#  'Amber Gray',
#  'Hans Zimmer',
#  'DAVICHI',
#  'Hans Zimmer',
#  'Paolo Buonvino',
#  'Sawano Hiroyuki',
#  'Kyle Dixon & Michael Stein',
#  'Kyle Dixon & Michael Stein',
#  'Hans Zimmer',
#  'Sawano Hiroyuki',
#  'RoomTone',
#  'Kyle Dixon & Michael Stein',
#  'Andrew Prahlow',
#  'Thomas Newman',
#  'Ludvig Forssell',
#  'Kyle Dixon & Michael Stein',
#  'Ramin Djawadi',
#  'Kyle Dixon & Michael Stein',
#  'Ramin Djawadi',
#  'UVERworld',
#  'Hoover',
#  'André De Shields',
#  'Kyle Dixon & Michael Stein',
#  'cinema staff',
#  'Carrie Hope Fletcher',
#  'Sawano Hiroyuki',
#  'Hans Zimmer',
#  'Kyle Dixon & Michael Stein',
#  '10CM',
#  'Andrew Prahlow',
#  'Agrupacion Musical Nuestro Padre Jesús Despojado de Jaen',
#  'Trevor Morris',
#  'Miyu Tomita',
#  'Akano',
#  'Jasna Zlokic',
#  'Sarah Ndagire',
#  'Aidar BMM',
#  'Krunoslav Kićo Slabinac',
#  'Meri Cetinic',
#  'Stan Van Samang',
#  'Группа 101',
#  'Tereza Kesovija',
#  'Tereza Kesovija',
#  'Jay A',
#  'Hari Rončević',
#  'Đani Maršan',
#  '2nd Moon',
#  'Ivo Pattiera',
#  'Fadhili William',
#  'Stan Van Samang',
#  'Hari Rončević',
#  'Krunoslav Kićo Slabinac',
#  'Sarah Ndagire',
#  'Vinko Coce',
#  'Ivo Pattiera',
#  'Арай',
#  'Sarah Ndagire',
#  'Tereza Kesovija',
#  'Tural Everest',
#  'Айкын',
#  'Đani Maršan',
#  'Badal Paul',
#  'Dinara Sultan',
#  'Raj Negi',
#  'Lalitya Munshaw',
#  'Klapa Cambi (Kaštel Kambelovac)',
#  'Badal Paul',
#  'Айкын',
#  'Ivo Pattiera',
#  'Klapa Maslina',
#  'Valeriya',
#  'Группа 101',
#  'Tereza Kesovija',
#  'Dalmatino',
#  'Lalitya Munshaw',
#  'Tereza Kesovija',
#  'Đani Maršan',
#  'Jabu Khanyile',
#  'Tereza Kesovija',
#  'Collo',
#  'Krunoslav-Kićo Slabinac',
#  'Sarah Ndagire',
#  'Đani Maršan',
#  'Группа 101',
#  'Ivo Pattiera',
#  'Klapa Puntamika',
#  'Tereza Kesovija',
#  'Tarin',
#  'Tomislav Bralic',
#  'Tereza Kesovija',
#  'Datuk Ahmad Jais',
#  'Gonzaga Coutinho',
#  'Stan Van Samang',
#  'Afrigo Band',
#  'Đani Maršan',
#  'Klapa Maslina',
#  'Klapa Cambi (Kaštel Kambelovac)',
#  'Đani Maršan',
#  'Klapa Sufit',
#  'Jabu Khanyile',
#  'Tereza Kesovija',
#  'Đani Maršan',
#  'Stimela',
#  'Badal Paul',
#  'Jabu Khanyile',
#  'Айкын',
#  'Sarah Ndagire',
#  'Aidar BMM',
#  'Krunoslav Kićo Slabinac',
#  'Ivo Pattiera',
#  'Cho Yong Pil',
#  'Krunoslav Kićo Slabinac',
#  'Urbanus',
#  'Krunoslav Kićo Slabinac',
#  'Арай',
#  'Stan Van Samang',
#  'Badal Paul',
#  'Klapa Maslina',
#  'D.Holic',
#  'Krunoslav Kićo Slabinac',
#  'Đani Maršan',
#  'Kwaya Ya Uinjilisti Ya Vijana Arusha Mjini',
#  'Lalitya Munshaw',
#  'Đani Maršan',
#  '2nd Moon',
#  'Lalitya Munshaw',
#  'Đani Maršan',
#  'Kumar Pritam',
#  'Lalitya Munshaw',
#  'Joo Yein',
#  'Meri Cetinic',
#  'Klapa Sufit',
#  'Raj Negi',
#  'Đani Maršan',
#  'Edita Sopjani',
#  'Tereza Kesovija',
#  'Klapa Iskon',
#  'Арай',
#  'Đani Maršan',
#  'Tereza Kesovija',
#  'Jasna Zlokic',
#  'Krunoslav Kićo Slabinac',
#  'Kim Yuna',
#  'Tereza Kesovija',
#  'Jabu Khanyile',
#  'Ivo Pattiera',
#  'Stan Van Samang',
#  'Klapa Maslina',
#  'Tereza Kesovija',
#  'Ivo Pattiera',
#  'Dinara Sultan',
#  'Đani Maršan',
#  'Hari Rončević',
#  'Tereza Kesovija',
#  'Teresa Teng',
#  'Klapa Maslina',
#  'Арай',
#  'Tereza Kesovija',
#  'Группа 101',
#  'Sarah Ndagire',
#  'Sarah Ndagire',
#  'Lalitya Munshaw',
#  'Tereza Kesovija',
#  'Klapa Maslina',
#  'Krunoslav Kićo Slabinac',
#  'Klapa Sufit',
#  'Krunoslav Kićo Slabinac',
#  'Sarah Ndagire',
#  'Teresa Teng',
#  'Jasna Zlokic',
#  'Vinko Coce',
#  'Đani Maršan',
#  'Lalitya Munshaw',
#  'Ivo Pattiera',
#  'Afrigo Band',
#  'Saro Vardanyan',
#  'Группа 101',
#  'Stimela',
#  'Tereza Kesovija',
#  'Aidar BMM',
#  'Joo Yein',
#  'Kwaya Ya Uinjilisti Ya Vijana Arusha Mjini',
#  'Meri Cetinic',
#  'Арай',
#  'Naveen Pathak',
#  'Stan Van Samang',
#  'Veli Sahiti',
#  'Ronny Mosuse',
#  'Lawrence P Dsouza',
#  'Prelude',
#  'Amani',
#  'Stan Van Samang',
#  'Amani',
#  'Flaka Krelani',
#  'Lalitya Munshaw',
#  'Klapa Cambi',
#  'Tereza Kesovija',
#  'Han All',
#  'Da Gudda Jazz',
#  'Meri Cetinic',
#  'Tereza Kesovija',
#  'Flaka Krelani',
#  'Meri Cetinic',
#  'Tomislav Ivčić',
#  'Veli Sahiti',
#  'Lee Mi Ja',
#  'Stan Van Samang',
#  'Kim Young-Im',
#  'Jagmohan Digari',
#  'Jasna Zlokic',
#  'Naveen Pathak',
#  'Lawrence P Dsouza',
#  'Naveen Pathak',
#  'Naveen Pathak',
#  'Naveen Pathak',
#  'OKDAL',
#  'Koen Crucke',
#  'Tereza Kesovija',
#  'Iwan Esseboom',
#  'Naveen Pathak',
#  'Tereza Kesovija',
#  'Koen Crucke',
#  'Stan Van Samang',
#  'Ivo Pattiera',
#  'Da Gudda Jazz',
#  'Stan Van Samang',
#  'Tereza Kesovija',
#  'Amani',
#  'Meri Cetinic',
#  'Nam Jin',
#  'Meri Cetinic',
#  'Kim Young-Im',
#  'Jay Jay',
#  'Remzie Osmani',
#  'Natali',
#  'Idiot Glee',
#  'Jang Pill Soon',
#  'Naveen Pathak',
#  'Lee Mi Ja',
#  'Lalitya Munshaw',
#  'Stan Van Samang',
#  'Kim Young-Im',
#  'Lalitya Munshaw',
#  'Veli Sahiti',
#  'Naveen Pathak',
#  'Tereza Kesovija',
#  'Tereza Kesovija',
#  'Flaka Krelani',
#  'Jagmohan Digari',
#  'Jay A',
#  'Lalitya Munshaw',
#  'Iwan Esseboom',
#  'Meri Cetinic',
#  'Ivo Pattiera',
#  'Sunny Hill',
#  'Tereza Kesovija',
#  'Vicmass Luodollar',
#  'Загир Сатыров',
#  'Sidar Beritan',
#  'Meri Cetinic',
#  'Jasna Zlokic',
#  'Ivo Pattiera',
#  'Kim Young-Im',
#  'Lalitya Munshaw',
#  'Stan Van Samang',
#  'Tereza Kesovija',
#  'Koen Crucke',
#  'Kim Young-Im',
#  'Bae Ho',
#  'Nikolay Baskov',
#  'Tereza Kesovija',
#  'Iwan Esseboom',
#  'Tereza Kesovija',
#  'Lee Mi Ja',
#  'Ivo Pattiera',
#  'Lalitya Munshaw',
#  'Iwan Esseboom',
#  'Tereza Kesovija',
#  'Lee Mi Ja',
#  'Kim Young-Im',
#  'Koen Crucke',
#  'Klapa Sufit',
#  'Veli Sahiti',
#  'Choi JinHee',
#  ...]

# %%
len(df_spotify['artist_name'].tolist()) # Número de registros de la extración de datos de la API Spotipy
# Out:
# 3000

# %%
unique_artists_spotify = df_spotify['artist_name'].unique().tolist() # Generar valores únicos de artistas de la extración de datos de la API Spotipy

# %%
len(unique_artists_spotify) # Número de registros unicos de artistas de la extración de datos de la API Spotipy
# Out:
# 1141

# %%
lista_artist_lastfm_NN = [] # Variable para almacenar toda la información de todos los artistas que no sean nulos.

for X in unique_artists_spotify:
    info = get_artist_info(X)
    if info is not None:  # solo agrega si tiene datos
        lista_artist_lastfm_NN.append(info)
    time.sleep(0.5)
# Out:
# ❌ Error de la API LastFM: The artist you supplied could not be found
# ❌ Error de la API LastFM: The artist you supplied could not be found
# ❌ HTTP 500 para el artista: Pastaboys
# ❌ HTTP 500 para el artista: Teni

# %%
len(lista_artist_lastfm_NN) # Número de registros unicos de artistas de la extración de datos de la API LastFM
# Out:
# 1137

# %%
df_lastfm = pd.DataFrame(lista_artist_lastfm_NN) # Transformación en DataFrame

# %%
df_lastfm
# Out:
#                           artist_name  \
# 0                        Daveed Diggs
# 1                        Phillipa Soo
# 2                      Jonathan Groff
# 3                  Lin-Manuel Miranda
# 4     Fear, and Loathing in Las Vegas
# ...                               ...
# 1132                       Chop Daily
# 1133                            Praiz
# 1134                  Marco Avitabile
# 1135                        Lola Jane
# 1136                           Masego
#
#                                               biography listeners playcount  \
# 0     Daveed Daniele Diggs (born January 24, 1982 in...    415158   4996907
# 1     Phillipa Soo (born May 31, 1990) is an America...    579996  15510216
# 2     Jonathan Groff is an American stage performer ...    748179  13189716
# 3     Lin-Manuel Miranda (born January 16, 1980 in N...    722417  26857358
# 4     Fear, and Loathing in Las Vegas is a electroni...    222284   8167150
# ...                                                 ...       ...       ...
# 1132   <a href="https://www.last.fm/music/Chop+Daily...     77762    620161
# 1133  Praise Ugbede Adejo (born 8 March 1984), bette...     20392    120860
# 1134   <a href="https://www.last.fm/music/Marco+Avit...      1276      3704
# 1135   <a href="https://www.last.fm/music/Lola+Jane"...      5905     52454
# 1136  Micah Davis (born June 8, 1993), better known ...   1035548  20285573
#
#                           similar_artist
# 0                    Christopher Jackson
# 1                    Christopher Jackson
# 2     Original Broadway Cast of Hamilton
# 3                        Leslie Odom Jr.
# 4                   a crowd of rebellion
# ...                                  ...
# 1132                     Keys the Prince
# 1133                             Banky W
# 1134                     Peppe Citarella
# 1135                     Archie & Sizzle
# 1136                                 SiR
#
# [1137 rows x 5 columns]

# %%
df_lastfm.to_csv("artistas-lastfm.csv", index=False) #Extraccion LastFM to CSV

# %%
df_artists_lastfm = pd.read_csv("artistas-lastfm.csv") # Lectura de CSV
df_artists_lastfm
# Out:
#                           artist_name  \
# 0                        Daveed Diggs
# 1                        Phillipa Soo
# 2                      Jonathan Groff
# 3                  Lin-Manuel Miranda
# 4     Fear, and Loathing in Las Vegas
# ...                               ...
# 1132                       Chop Daily
# 1133                            Praiz
# 1134                  Marco Avitabile
# 1135                        Lola Jane
# 1136                           Masego
#
#                                               biography  listeners  playcount  \
# 0     Daveed Daniele Diggs (born January 24, 1982 in...     415158    4996907
# 1     Phillipa Soo (born May 31, 1990) is an America...     579996   15510216
# 2     Jonathan Groff is an American stage performer ...     748179   13189716
# 3     Lin-Manuel Miranda (born January 16, 1980 in N...     722417   26857358
# 4     Fear, and Loathing in Las Vegas is a electroni...     222284    8167150
# ...                                                 ...        ...        ...
# 1132   <a href="https://www.last.fm/music/Chop+Daily...      77762     620161
# 1133  Praise Ugbede Adejo (born 8 March 1984), bette...      20392     120860
# 1134   <a href="https://www.last.fm/music/Marco+Avit...       1276       3704
# 1135   <a href="https://www.last.fm/music/Lola+Jane"...       5905      52454
# 1136  Micah Davis (born June 8, 1993), better known ...    1035548   20285573
#
#                           similar_artist
# 0                    Christopher Jackson
# 1                    Christopher Jackson
# 2     Original Broadway Cast of Hamilton
# 3                        Leslie Odom Jr.
# 4                   a crowd of rebellion
# ...                                  ...
# 1132                     Keys the Prince
# 1133                             Banky W
# 1134                     Peppe Citarella
# 1135                     Archie & Sizzle
# 1136                                 SiR
#
# [1137 rows x 5 columns]

# %%
def clean_html_links(text):
    if not isinstance(text, str):
        return text
    
    # Reemplaza <a href="URL">texto</a> → URL
    text = re.sub(r'<a href="(https?://[^"]+)".*?>.*?</a>', r'\1', text)

    # Quita cualquier otra etiqueta HTML que quede
    text = re.sub(r'<.*?>', '', text)

    return text.strip()


df_artists_lastfm = pd.read_csv("artistas-lastfm.csv")

for i, artist in enumerate(df_artists_lastfm["artist_name"], start=1):
    biography_text = df_artists_lastfm.loc[i-1, "biography"]     
    cleaned_text = clean_html_links(biography_text)    #aquí limpiamos el codigo HTML
    df_artists_lastfm.loc[i-1, "biography"] = cleaned_text  #guardamos el texto limpio en la misma celda
    print(f"{i}. ✅ {artist}")
    time.sleep(0.25)
# Out:
# 1079. ✅ Dollar DJ
# 1080. ✅ Ivan Alekxei
# 1081. ✅ DopeNation
# 1082. ✅ Lady Donli
# 1083. ✅ Silvano Del Gado
# 1084. ✅ Kwesi Arthur
# 1085. ✅ Yas Cepeda
# 1086. ✅ Gerilson Insrael
# 1087. ✅ SHIMZA
# 1088. ✅ ecool
# 1089. ✅ BM
# 1090. ✅ Flash
# 1091. ✅ Lisa Shaw
# 1092. ✅ Quatro
# 1093. ✅ Studio Bros
# 1094. ✅ Kuami Eugene
# 1095. ✅ Themba
# 1096. ✅ Konde
# 1097. ✅ Master KG
# 1098. ✅ Armonica
# 1099. ✅ Yola Semedo
# 1100. ✅ Ayüü
# 1101. ✅ Mystro
# 1102. ✅ DARKoO
# 1103. ✅ Fireboy DML
# 1104. ✅ Joeboy
# 1105. ✅ DJ anilson
# 1106. ✅ Beyoncé
# 1107. ✅ Rotimi
# 1108. ✅ Ckay
# 1109. ✅ Plaster Hands
# 1110. ✅ Rema
# 1111. ✅ Nico Morano
# 1112. ✅ Jorja Smith
# 1113. ✅ Kojo Funds
# 1114. ✅ Tyla
# 1115. ✅ Omah Lay
# 1116. ✅ Sebjak
# 1117. ✅ Kobi Jonz
# 1118. ✅ Brandz
# 1119. ✅ Rui Orlando
# 1120. ✅ Pato's Groove
# 1121. ✅ Claudio Fênix
# 1122. ✅ Mahalia
# 1123. ✅ Odunsi (The Engine)
# 1124. ✅ Sauti Sol
# 1125. ✅ Adekunle GOLD
# 1126. ✅ Amaarae
# 1127. ✅ Crayon
# 1128. ✅ Cubita
# 1129. ✅ Chris Brown
# 1130. ✅ PAAX (Tulum)
# 1131. ✅ Simone Vitullo
# 1132. ✅ Duda
# 1133. ✅ Chop Daily
# 1134. ✅ Praiz
# 1135. ✅ Marco Avitabile
# 1136. ✅ Lola Jane
# 1137. ✅ Masego

# %%
df_artists_lastfm.tail(10)
# Out:
#           artist_name                                          biography  \
# 1127           Cubita                   https://www.last.fm/music/Cubita
# 1128      Chris Brown  Christopher Maurice Brown (born May 5, 1989) i...
# 1129     PAAX (Tulum)             https://www.last.fm/music/PAAX+(Tulum)
# 1130   Simone Vitullo  Simone Vitullo DJ and house music producer for...
# 1131             Duda  There are two groups using the name Duda one f...
# 1132       Chop Daily               https://www.last.fm/music/Chop+Daily
# 1133            Praiz  Praise Ugbede Adejo (born 8 March 1984), bette...
# 1134  Marco Avitabile          https://www.last.fm/music/Marco+Avitabile
# 1135        Lola Jane                https://www.last.fm/music/Lola+Jane
# 1136           Masego  Micah Davis (born June 8, 1993), better known ...
#
#       listeners  playcount      similar_artist
# 1127       5604      52004        Nuno Ribeiro
# 1128    4694935  154333464  Chris Brown & Tyga
# 1129      41100     283484            Antaares
# 1130      23050     108481            Chambord
# 1131       7143      78402               Peled
# 1132      77762     620161     Keys the Prince
# 1133      20392     120860             Banky W
# 1134       1276       3704     Peppe Citarella
# 1135       5905      52454     Archie & Sizzle
# 1136    1035548   20285573                 SiR

# %%
df_artists_lastfm.to_csv("artistas-lastfm.csv", index=False) #Extraccion LastFM to CSV
