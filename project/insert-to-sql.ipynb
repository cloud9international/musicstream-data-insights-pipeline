# %% [markdown]
# ### INSERT DATA TO SQL

# %%
import os 
from dotenv import load_dotenv 
load_dotenv()

import mysql.connector 
import pandas as pd

# %%
# conectar con mysql
cnx = mysql.connector.connect(
    user=os.getenv("MYSQL_USER"),
    password=os.getenv("MYSQL_PASSWORD"),
    host=os.getenv("MYSQL_HOST"),
    database=os.getenv("MYSQL_DATABASE"),
    autocommit=False
)

cursor = cnx.cursor()

# %%
# importar .csv para tener un DataFrame
df_lastfm = pd.read_csv("artistas-lastfm.csv")
df_spotify = pd.read_csv('canciones-spotify.csv')

# %%
# Ajustar nombre de columna para que coincida con MySQL
df_lastfm = df_lastfm.rename(columns={"similar_artist": "similar_artists"})

# %%
# error en la linea 72 - año solo 2015

df_spotify.head(73)
# Out:
#                         id             track_name  \
# 0   0LpHC9mhPAQC98IjXZIrif   The Election of 1800
# 1   6oF8ueLn5hIl4PRp17sxW6   That Would Be Enough
# 2   4eeN8erNIbW2osT0knz5vT             I Know Him
# 3   3lXyAQ0kekAvY5LodpWmUs  Ten Duel Commandments
# 4   1llkMtLL4vbe0pr3NV2ckg            Let Me Hear
# ..                     ...                    ...
# 68  4XX5uZb9PvTKh8Nm2KSJfk       Once Upon a Time
# 69  3eQijz4pPT7rb020LqdhdX         Another Medium
# 70  6ZT36tXEKY2vvTCuNK4fi1          Metal Crusher
# 71  2ydKgIVZAQXeYLWtxU8DFS   Stay Alive - Reprise
# 72  05bhmaAD1urZnQMWNd6p3S      Schuyler Defeated
#
#                         artist_name  year       genre album_type release_date  \
# 0                      Daveed Diggs  2015  soundtrack      album   2015-09-25
# 1                      Phillipa Soo  2015  soundtrack      album   2015-09-25
# 2                    Jonathan Groff  2015  soundtrack      album   2015-09-25
# 3                Lin-Manuel Miranda  2015  soundtrack      album   2015-09-25
# 4   Fear, and Loathing in Las Vegas  2015  soundtrack      album   2015-09-30
# ..                              ...   ...         ...        ...          ...
# 68                         Toby Fox  2015  soundtrack      album   2015-09-15
# 69                         Toby Fox  2015  soundtrack      album   2015-09-15
# 70                         Toby Fox  2015  soundtrack      album   2015-09-15
# 71               Lin-Manuel Miranda  2015  soundtrack      album   2015-09-25
# 72                     Phillipa Soo  2015  soundtrack      album   2015-09-25
#
#     popularity
# 0           65
# 1           66
# 2           65
# 3           67
# 4           59
# ..         ...
# 68          56
# 69          56
# 70          54
# 71          62
# 72          63
#
# [73 rows x 8 columns]

# %%
df_lastfm.tail(10)
# Out:
#           artist_name                                          biography  \
# 1127           Cubita                   https://www.last.fm/music/Cubita
# 1128      Chris Brown  Christopher Maurice Brown (born May 5, 1989) i...
# 1129     PAAX (Tulum)             https://www.last.fm/music/PAAX+(Tulum)
# 1130   Simone Vitullo  Simone Vitullo DJ and house music producer for...
# 1131             Duda  There are two groups using the name Duda one f...
# 1132       Chop Daily               https://www.last.fm/music/Chop+Daily
# 1133            Praiz  Praise Ugbede Adejo (born 8 March 1984), bette...
# 1134  Marco Avitabile          https://www.last.fm/music/Marco+Avitabile
# 1135        Lola Jane                https://www.last.fm/music/Lola+Jane
# 1136           Masego  Micah Davis (born June 8, 1993), better known ...
#
#       listeners  playcount     similar_artists
# 1127       5604      52004        Nuno Ribeiro
# 1128    4694935  154333464  Chris Brown & Tyga
# 1129      41100     283484            Antaares
# 1130      23050     108481            Chambord
# 1131       7143      78402               Peled
# 1132      77762     620161     Keys the Prince
# 1133      20392     120860             Banky W
# 1134       1276       3704     Peppe Citarella
# 1135       5905      52454     Archie & Sizzle
# 1136    1035548   20285573                 SiR

# %%
# NULOS - convertir NULOS de NaN a None (para que SQL acepte los datos)
df_lastfm  = df_lastfm.where(pd.notnull(df_lastfm), None)
df_spotify = df_spotify.where(pd.notnull(df_spotify), None)

# %%
# IDEMPOTENCIA - Evitar duplicados: vaciar tablas antes de insertar
# Nota: esto borra los datos, pero mantiene la estructura de las tablas
try:
    cursor.execute("SET FOREIGN_KEY_CHECKS = 0;")
    cursor.execute("TRUNCATE TABLE spotify;")
    cursor.execute("TRUNCATE TABLE lastfm;")
    cnx.commit()
    print("✅ Tablas vaciadas. Listo para insertar sin duplicados.")
finally:
    cursor.execute("SET FOREIGN_KEY_CHECKS = 1;")
# Out:
# ✅ Tablas vaciadas. Listo para insertar sin duplicados.

# %%
# MySQL - insertar data en la tabla LastFM
sql_lastfm = """
INSERT INTO lastfm (artist_name, biography, listeners, playcount, similar_artists)
VALUES (%s, %s, %s, %s, %s)
"""

# Asegurar el orden de columnas para el INSERT
cols_lastfm = ["artist_name", "biography", "listeners", "playcount", "similar_artists"]

cursor.executemany(sql_lastfm, df_lastfm[cols_lastfm].values.tolist())
cnx.commit()

print(f"✅ Insertadas {cursor.rowcount} filas en 'lastfm'.")
# Out:
# ✅ Insertadas 1137 filas en 'lastfm'.

# %% [markdown]
# **Cambiar 'release_date' de   año '2015'   para   año completo '2015-01-01**

# %%
# Arreglar release_date cuando viene solo con el año (ej: "2015")
df_spotify["release_date"] = df_spotify["release_date"].astype(str)

mask_solo_anio = df_spotify["release_date"].str.len() == 4
df_spotify.loc[mask_solo_anio, "release_date"] = df_spotify.loc[mask_solo_anio, "release_date"] + "-01-01"

# Convertir a fecha (si algún valor es raro, queda como NaT)
df_spotify["release_date"] = pd.to_datetime(df_spotify["release_date"], errors="coerce").dt.date

# %%
df_spotify.head(20)
# Out:
#                         id                               track_name  \
# 0   0LpHC9mhPAQC98IjXZIrif                     The Election of 1800
# 1   6oF8ueLn5hIl4PRp17sxW6                     That Would Be Enough
# 2   4eeN8erNIbW2osT0knz5vT                               I Know Him
# 3   3lXyAQ0kekAvY5LodpWmUs                    Ten Duel Commandments
# 4   1llkMtLL4vbe0pr3NV2ckg                              Let Me Hear
# 5   7cAexYA1vH6srKeIuKySud                               超絶☆ダイナミック!
# 6   1DLfR4MOfLYbV6v3xrmWa8                                  We Know
# 7   6SHI6STEW51cQkAXBRpLNj                    Your Obedient Servant
# 8   2qFIJT5hjqaNFA1GKwl9me                             Take a Break
# 9   733tju3KUeatsbjcTRQ04i  Yorktown (The World Turned Upside Down)
# 10  2W9u3whoCkQYOUbmnSrHi1                            What'd I Miss
# 11  46YSff2Rq1ZtN1YVk5cwbZ                              Brave Shine
# 12  3nJYcY9yvKP8Oi2Ml8brXt                           Right Hand Man
# 13  2yBMVrq96wb9OHbMdBs0lF                          A Winter's Ball
# 14  1mGO8rwCE9zk7H06OxcU5m              History Has Its Eyes on You
# 15  0wae8KoprNjfrXWjYYHGy9                         Spear of Justice
# 16  3aiGshuqYhdBBBhHqRf6jn                             Spider Dance
# 17  2sEq2rC3ynYsT49x7utWnd                           Dear Theodosia
# 18  1di1C0QI6Y92yZPYn6XYAZ                                    シルエット
# 19  1CzeuSrm71wHP9qsjg7p3F           The Story of Tonight - Reprise
#
#                            artist_name  year       genre album_type  \
# 0                         Daveed Diggs  2015  soundtrack      album
# 1                         Phillipa Soo  2015  soundtrack      album
# 2                       Jonathan Groff  2015  soundtrack      album
# 3                   Lin-Manuel Miranda  2015  soundtrack      album
# 4      Fear, and Loathing in Las Vegas  2015  soundtrack      album
# 5                        Kazuya Yoshii  2015  soundtrack     single
# 6                   Lin-Manuel Miranda  2015  soundtrack      album
# 7                      Leslie Odom Jr.  2015  soundtrack      album
# 8                         Phillipa Soo  2015  soundtrack      album
# 9   Original Broadway Cast of Hamilton  2015  soundtrack      album
# 10                        Daveed Diggs  2015  soundtrack      album
# 11                               Aimer  2015  soundtrack      album
# 12                  Lin-Manuel Miranda  2015  soundtrack      album
# 13                     Leslie Odom Jr.  2015  soundtrack      album
# 14                 Christopher Jackson  2015  soundtrack      album
# 15                            Toby Fox  2015  soundtrack      album
# 16                            Toby Fox  2015  soundtrack      album
# 17                     Leslie Odom Jr.  2015  soundtrack      album
# 18                           KANA-BOON  2015  soundtrack      album
# 19                 Okieriete Onaodowan  2015  soundtrack      album
#
#    release_date  popularity
# 0    2015-09-25          65
# 1    2015-09-25          66
# 2    2015-09-25          65
# 3    2015-09-25          67
# 4    2015-09-30          59
# 5    2015-10-07          55
# 6    2015-09-25          66
# 7    2015-09-25          66
# 8    2015-09-25          67
# 9    2015-09-25          68
# 10   2015-09-25          67
# 11   2015-07-29          62
# 12   2015-09-25          68
# 13   2015-09-25          68
# 14   2015-09-25          67
# 15   2015-09-15          59
# 16   2015-09-15          61
# 17   2015-09-25          68
# 18   2015-01-21          78
# 19   2015-09-25          66

# %%
# --- 1. Filtrar SPOTIFY para respetar el FOREIGN KEY ---
# Solo dejamos canciones cuyo 'artist_name' existe en la tabla LastFM
df_spotify = df_spotify[df_spotify["artist_name"].isin(df_lastfm["artist_name"])]

print(f"Filtrado por FK completado. Filas restantes en df_spotify: {len(df_spotify)}")
# Out:
# Filtrado por FK completado. Filas restantes en df_spotify: 2680

# %%
# --- 2. Identificar duplicados por 'id' ---
df_duplicados = df_spotify[df_spotify.duplicated(subset=['id'], keep=False)]

# --- 3. Conservar solo primeras ocurrencias ---
df_unicos = df_spotify.drop_duplicates(subset=['id'], keep='first')

# --- 4. Mostrar IDs duplicadas descartadas ---
print("--- 🛑 IDs duplicadas descartadas ---")
ids_duplicadas = df_duplicados[~df_duplicados.index.isin(df_unicos.index)]['id'].unique()

if ids_duplicadas.size == 0:
    print("No se encontraron IDs duplicadas.")
else:
    print(f"Se descartaron {len(ids_duplicadas)} IDs duplicadas:")
    for track_id in ids_duplicadas:
        print(f"❌ ID duplicada: {track_id}")

print(f"----------------------------------------------------------")
print(f"Total de filas únicas a insertar: {len(df_unicos)}")


# --- 5. Insertar las canciones ÚNICAS en MySQL ---
sql_spotify = """
INSERT INTO spotify (id, track_name, artist_name, `year`, genre, album_type, release_date, popularity)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
"""

# Asegurar el orden de columnas para el INSERT
cols_spotify = ["id", "track_name", "artist_name", "year", "genre", "album_type", "release_date", "popularity"]

try:
    cursor.executemany(sql_spotify, df_unicos[cols_spotify].values.tolist())
    cnx.commit()
    print(f"✅ ÉXITO: Se insertaron {cursor.rowcount} filas únicas en la tabla 'spotify'.")
except Exception as e:
    print(f"❌ ERROR durante la inserción final: {e}")
    cnx.rollback()
# Out:
# --- 🛑 IDs duplicadas descartadas ---
# Se descartaron 60 IDs duplicadas:
# ❌ ID duplicada: 72J8YcwCwa4mEKC5ejTEer
# ❌ ID duplicada: 3JHJV0ATUoKJT6mZKiAViT
# ❌ ID duplicada: 0WiZqYM92ppK3M3FdpCTTw
# ❌ ID duplicada: 255wo3uvC0gORTc3jb8GiY
# ❌ ID duplicada: 3FesugTZgJ8SiA4mMKkufK
# ❌ ID duplicada: 6PoMhappYRfHHTmEhki7mg
# ❌ ID duplicada: 0pDtV1UZNOy1tr7BIvXvb2
# ❌ ID duplicada: 790egsd71LLOVAxnRIPfZN
# ❌ ID duplicada: 2jbK4mjePUHe4MBLLKTD4p
# ❌ ID duplicada: 1cPWDVYZMnxoYjYeqoxZcQ
# ❌ ID duplicada: 1gqlyWcGelFrxUkU6717Cw
# ❌ ID duplicada: 6X2ZeyRIkDS2agHBEAj9Av
# ❌ ID duplicada: 2ZsHTWXlJb6wIMcJAl0GUt
# ❌ ID duplicada: 22ZyuwMDnaK3JEu3KDRuiD
# ❌ ID duplicada: 7t7S0VpHgPAl2AqKYbDEy3
# ❌ ID duplicada: 5RdOAhOquiIseyWtxHmLRr
# ❌ ID duplicada: 4HrYGKCfEpfJxbXFQfOsFO
# ❌ ID duplicada: 2CCnb2cYymAvad46etfqLo
# ❌ ID duplicada: 0UXD0WRnJEdfLQ7kVEGdXw
# ❌ ID duplicada: 2iQQDh49tRELI79nFrTkM2
# ❌ ID duplicada: 7Gilv913H0QfaMyGxfebqc
# ❌ ID duplicada: 7yeli0qRvVyxCeHtZJKWjr
# ❌ ID duplicada: 2fluT6PPAE7cAuEXQD0QeA
# ❌ ID duplicada: 7wcuQDBeaFIyMAcNY806on
# ❌ ID duplicada: 0S3XyiJXJkbuRoBeeHUKPP
# ❌ ID duplicada: 7tMms2nEe7HL574vyUL0d3
# ❌ ID duplicada: 2gdc26Rj4z3LgiaIzjly9h
# ❌ ID duplicada: 4p413IsW9UoaPQ5SefIy9F
# ❌ ID duplicada: 4rLhODv5yRfu9yJuv0MIK3
# ❌ ID duplicada: 4HKDE8vGHNGgrDyzoa1Cuj
# ❌ ID duplicada: 3ezLR0SNRDes6f3WGbL5g6
# ❌ ID duplicada: 3zloCRWnz5QMEoIH3XpwgX
# ❌ ID duplicada: 5bchl3X6vJeImaEkM0i3an
# ❌ ID duplicada: 2R8utI3BTwJpl7qMIYadNK
# ❌ ID duplicada: 2uVWDKsKP7ayFaqJuTRuER
# ❌ ID duplicada: 6piKMHvO3GOJg4Pvo6OLoV
# ❌ ID duplicada: 1D2IsOcjP6CGtmW2xtmadv
# ❌ ID duplicada: 1XXbQzLoNMnBCznomoKKQ1
# ❌ ID duplicada: 6ey415Wsh8GqLYJJ2Sy0xf
# ❌ ID duplicada: 7navNwzjb1SAYPbqRSbIJL
# ❌ ID duplicada: 6j8MdaHoTQ6LshKz2bWBIx
# ❌ ID duplicada: 0YUxsc7Pa6UNura6atr7XK
# ❌ ID duplicada: 17N1FsMdiBibhEUnNzzTAx
# ❌ ID duplicada: 6lEwKLXXHi6SkEddlkKero
# ❌ ID duplicada: 6dUhdEBRfypETdqfAXCQy9
# ❌ ID duplicada: 7LD54ncErLJAlkLFsn0I9X
# ❌ ID duplicada: 1D0br0fmbBU2bL8mH1YYvs
# ❌ ID duplicada: 5ZeGNNponFciFdJiUGDAJU
# ❌ ID duplicada: 7r0hmocoHz3MgDlhjPnUmj
# ❌ ID duplicada: 7anaP80m3viF7wQD6Yq0H1
# ❌ ID duplicada: 3GVFQoy9T4TZV49X2eHx6z
# ❌ ID duplicada: 4nDS9vv8cVsc4qo5uHCpqQ
# ❌ ID duplicada: 6eqzWDpRdVJPPppHZ3lRex
# ❌ ID duplicada: 1TE7wgyYr9EsNvhRNjsDiq
# ❌ ID duplicada: 6TfUxcjSjPP4GoFCYXNy1d
# ❌ ID duplicada: 2U2EHgStganM7eTO2HBOEn
# ❌ ID duplicada: 3t1oP8heQ4jlfxEJUzmo0T
# ❌ ID duplicada: 0YhkWKA8ja2Gwu3ORyXVrx
# ❌ ID duplicada: 68gzf3AleOyt4NlKwpV0MY
# ❌ ID duplicada: 11RIJRbBfyLlJut96itSFd
# ----------------------------------------------------------
# Total de filas únicas a insertar: 2620
# ✅ ÉXITO: Se insertaron 2620 filas únicas en la tabla 'spotify'.

# %%
# Verificar conteo de filas
cursor.execute("SELECT COUNT(*) FROM lastfm;")
print("lastfm:", cursor.fetchone()[0])

cursor.execute("SELECT COUNT(*) FROM spotify;")
print("spotify:", cursor.fetchone()[0])
# Out:
# lastfm: 1137
# spotify: 2620

# %%
cursor.close()
cnx.close()
print("✅ Conexión cerrada.")
# Out:
# ✅ Conexión cerrada.
