# %% [markdown]
# ### INSERT DATA TO SQL

# %%
import mysql.connector
from mysql.connector import errorcode
import pandas as pd

# %%
# conectar con mysql -- cambiar PASSWORD! ;)
cnx = mysql.connector.connect(
            user='root',
            password='Fefs1512',
            host='127.0.0.1')

cursor = cnx.cursor()

# %%
cursor.execute("USE musicstream_team_2")

# %%
cnx.database
# Out:
# 'musicstream_team_2'

# %%
# importar .csv para tener un DataFrame
df_lastfm = pd.read_csv('Artistas_LastFM.csv')
df_spotify = pd.read_csv('Canciones_Spotify.csv')

# %%
# error en la linea 72 - año solo 2015

df_spotify.head(73)
# Out:
#                         id                track_name  \
# 0   1WHNqqRWhJVZIdCScFKtl5   Washington on Your Side
# 1   1DLfR4MOfLYbV6v3xrmWa8                   We Know
# 2   2AtC6i0b8TjpjhWBZYLprX               Bonetrousle
# 3   6oF8ueLn5hIl4PRp17sxW6      That Would Be Enough
# 4   46YSff2Rq1ZtN1YVk5cwbZ               Brave Shine
# ..                     ...                       ...
# 68  5L9MJsGqzTRD09rSzHkCDy                      Home
# 69  6YTc18izaUvCS2XD7rK9Am          Dance of Dragons
# 70  3TfKt8mPpdXfQTMfRjHzyz         Cabinet Battle #1
# 71  4EnswQiF7J5MsB18ElZSS2  Esperanza Madre del Amor
# 72  0Lc3coQTcMMJiiEFi7BG2z              The Vagabond
#
#                                           artist_name  year       genre  \
# 0                                     Leslie Odom Jr.  2015  soundtrack
# 1                                  Lin-Manuel Miranda  2015  soundtrack
# 2                                            Toby Fox  2015  soundtrack
# 3                                        Phillipa Soo  2015  soundtrack
# 4                                               Aimer  2015  soundtrack
# ..                                                ...   ...         ...
# 68                                           Toby Fox  2015  soundtrack
# 69                                      Ramin Djawadi  2015  soundtrack
# 70                                Christopher Jackson  2015  soundtrack
# 71  Agrupacion Musical Nuestro Padre Jesús Despoja...  2015  soundtrack
# 72                                Marcin Przybyłowicz  2015  soundtrack
#
#    album_type release_date  popularity
# 0       album   2015-09-25          66
# 1       album   2015-09-25          66
# 2       album   2015-09-15          58
# 3       album   2015-09-25          67
# 4       album   2015-07-29          61
# ..        ...          ...         ...
# 68      album   2015-09-15          62
# 69      album   2015-06-09          46
# 70      album   2015-09-25          66
# 71      album         2015          25
# 72      album   2015-08-26          52
#
# [73 rows x 8 columns]

# %%
df_lastfm.tail(10)
# Out:
#          artist_name                                          biography  \
# 1188           Praiz  Praise Ugbede Adejo (born 8 March 1984), bette...
# 1189    Irina Barros             https://www.last.fm/music/Irina+Barros
# 1190    PAAX (Tulum)             https://www.last.fm/music/PAAX+(Tulum)
# 1191     Matt Sawyer              https://www.last.fm/music/Matt+Sawyer
# 1192          Cubita                   https://www.last.fm/music/Cubita
# 1193         Amaarae  Ama Serwah Genfi (born July 4, 1994), known pr...
# 1194     Chris Brown  Christopher Maurice Brown (born May 5, 1989) i...
# 1195       Lola Jane                https://www.last.fm/music/Lola+Jane
# 1196            Duda  There are two groups using the name Duda one f...
# 1197  Simone Vitullo  Simone Vitullo DJ and house music producer for...
#
#       listeners  playcount      similar_artist
# 1188      19973     117871            illBliss
# 1189       4786      44513         Rui Orlando
# 1190      39889     272297            Antaares
# 1191       1755       4391      Stereo Kulisse
# 1192       5383      50185        Nuno Ribeiro
# 1193     935034   30374468     Rochelle Jordan
# 1194    4598461  146850181  Chris Brown & Tyga
# 1195       5731      50670     Archie & Sizzle
# 1196       6635      69758               Peled
# 1197      21699     101880            Chambord

# %%
#NULOS - convertir NULOS de NaN a None (para que SQL acepte los datos)
df_lastfm  = df_lastfm.where(pd.notnull(df_lastfm), None)
df_spotify = df_spotify.where(pd.notnull(df_spotify), None)

# %%
# MySQL - inserir data en la tabla LastFM

sql_lastfm = """INSERT INTO lastfm (artist_name, biography, listeners, playcount, similar_artists)
                VALUES (%s, %s, %s, %s, %s)
"""
cursor.executemany(sql_lastfm, df_lastfm.values.tolist())

# %% [markdown]
# **Cambiar 'release_date' de   año '2015'   para   año completo '2015-01-01**

# %%
# 1. Asegurar que la columna 'release_date' sea de tipo string para operar sobre el formato.
df_spotify['release_date'] = df_spotify['release_date'].astype(str)

# 2. Crear una condición: ¿Tiene el valor exactamente 4 caracteres (solo año)?
# Esto identifica '2015' pero excluye '2015-10-25' (que tiene 10 caracteres).
condicion_solo_anio = (df_spotify['release_date'].str.len() == 4)

# 3. Aplicar la corrección usando .loc:
# En las filas donde la condición es VERDADERA, añadimos '-01-01' al final.
df_spotify.loc[condicion_solo_anio, 'release_date'] = \
    df_spotify.loc[condicion_solo_anio, 'release_date'] + '-01-01'

# 4. (Opcional pero muy recomendado) Convertir la columna al tipo datetime de Pandas
# Esto valida que todos los valores ahora son fechas válidas.
df_spotify['release_date'] = pd.to_datetime(df_spotify['release_date'], errors='coerce')

# %%
# revisando el error de la linea 72

df_spotify.head(1407)
# Out:
#                           id               track_name         artist_name  \
# 0     1WHNqqRWhJVZIdCScFKtl5  Washington on Your Side     Leslie Odom Jr.
# 1     1DLfR4MOfLYbV6v3xrmWa8                  We Know  Lin-Manuel Miranda
# 2     2AtC6i0b8TjpjhWBZYLprX              Bonetrousle            Toby Fox
# 3     6oF8ueLn5hIl4PRp17sxW6     That Would Be Enough        Phillipa Soo
# 4     46YSff2Rq1ZtN1YVk5cwbZ              Brave Shine               Aimer
# ...                      ...                      ...                 ...
# 1402  4YRZwIAblxzxkf78IbUNhp                  Gundeme      Hozan Muzaffer
# 1403  7djeEwxzTz9ToI03p6RRjM        Neem Ke Patiya Pe           Rajiv Raj
# 1404  6Dr2LqP1dadmZW3eQLGKim              Do Dat Tih$              Rabbit
# 1405  5epJh0RcVEMC4qxsJIikbZ              Telmın Çiye        Hozan Serwan
# 1406  6r53EJbzzzC2HGIHOmuNve                 Darabiye        Hozan Şervan
#
#       year       genre   album_type release_date  popularity
# 0     2015  soundtrack        album   2015-09-25          66
# 1     2015  soundtrack        album   2015-09-25          66
# 2     2015  soundtrack        album   2015-09-15          58
# 3     2015  soundtrack        album   2015-09-25          67
# 4     2015  soundtrack        album   2015-07-29          61
# ...    ...         ...          ...          ...         ...
# 1402  2019       k-pop        album   2019-04-01           0
# 1403  2019       k-pop  compilation   2019-09-25           0
# 1404  2019       k-pop       single   2019-12-29           0
# 1405  2019       k-pop        album   2019-06-26           0
# 1406  2019       k-pop        album   2019-06-20           0
#
# [1407 rows x 8 columns]

# %%
# MySQL - inserir data en la tabla Spotify

#sql_spotify = """INSERT INTO spotify (id, track_name, artist_name, `year`, genre, album_type, release_date, popularity)
                #VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
#"""
#cursor.executemany(sql_spotify, df_spotify.values.tolist())
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/mysql/connector/connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Duplicate entry '1Ogp6LEB5Qw1kl0pmpRJwo' for key 'spotify.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[133], line 6
#       1 # MySQL - inserir data en la tabla Spotify
#       3 sql_spotify = """INSERT INTO spotify (id, track_name, artist_name, `year`, genre, album_type, release_date, popularity)
#       4                 VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
#       5 """
# ----> 6 cursor.executemany(sql_spotify, df_spotify.values.tolist())
#
# File /opt/anaconda3/lib/python3.13/site-packages/mysql/connector/cursor_cext.py:473, in CMySQLCursor.executemany(self, operation, seq_params)
#     471     if stmt is not None:
#     472         self._executed = stmt
# --> 473         return self.execute(cast(str, stmt))
#     475 rowcnt = 0
#     476 try:
#     477     # When processing read ops (e.g., SELECT), rowcnt is updated
#     478     # based on self._rowcount. For write ops (e.g., INSERT) is
#     479     # updated based on self._affected_rows.
#     480     # The variable self._description is None for write ops, that's
#     481     # why we use it as indicator for updating rowcnt.
#
# File /opt/anaconda3/lib/python3.13/site-packages/mysql/connector/cursor_cext.py:353, in CMySQLCursor.execute(self, operation, params, map_results)
#     345 self._executed = (
#     346     self._stmt_partition["single_stmts"].popleft()
#     347     if map_results
#     348     else self._stmt_partition["mappable_stmt"]
#     349 )
#     351 try:
#     352     self._handle_result(
# --> 353         self._connection.cmd_query(
#     354             self._stmt_partition["mappable_stmt"],
#     355             raw=self._raw,
#     356             buffered=self._buffered,
#     357             raw_as_string=self._raw_as_string,
#     358         )
#     359     )
#     360 except MySQLInterfaceError as err:
#     361     if hasattr(err, "errno"):
#
# File /opt/anaconda3/lib/python3.13/site-packages/mysql/connector/opentelemetry/context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File /opt/anaconda3/lib/python3.13/site-packages/mysql/connector/connection_cext.py:781, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     779 except MySQLInterfaceError as err:
#     780     if hasattr(err, "errno"):
# --> 781         raise get_mysql_exception(
#     782             err.errno, msg=err.msg, sqlstate=err.sqlstate
#     783         ) from err
#     784     raise InterfaceError(str(err)) from err
#     785 except AttributeError as err:
#
# IntegrityError: 1062 (23000): Duplicate entry '1Ogp6LEB5Qw1kl0pmpRJwo' for key 'spotify.PRIMARY'

# %%
# 1. Identificar Duplicados
# Usamos el campo 'id' (tu clave primaria) para buscar filas duplicadas.
# 'keep=False' marca *todas* las instancias de un duplicado (la primera y las posteriores).
df_duplicados = df_spotify[df_spotify.duplicated(subset=['id'], keep=False)]

# 2. Obtener Solo Filas Únicas
# 'keep="first"' mantiene la primera aparición de cada 'id' único y descarta el resto.
df_unicos = df_spotify.drop_duplicates(subset=['id'], keep='first')

# 3. Mostrar las IDs que serán descartadas
print("--- 🛑 ATENCIÓN: IDs de canciones repetidas descartadas ---")
# Filtramos df_duplicados para mostrar solo las que NO están en df_unicos
ids_duplicadas = df_duplicados[~df_duplicados.index.isin(df_unicos.index)]['id'].unique()

if ids_duplicadas.size == 0:
    print("No se encontraron IDs duplicadas en el DataFrame.")
else:
    print(f"Se encontraron y descartaron {len(ids_duplicadas)} IDs duplicadas:")
    for track_id in ids_duplicadas:
        # Aquí puedes ajustar qué información quieres mostrar (ej: solo la ID)
        print(f"❌ ID: {track_id}")

print("----------------------------------------------------------")
print(f"Datos a insertar: {len(df_unicos)} filas únicas.")


# 4. Insertar los Datos Únicos en MySQL
sql_spotify = """INSERT INTO spotify (id, track_name, artist_name, `year`, genre, album_type, release_date, popularity)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
"""

try:
    # Usamos df_unicos (sin duplicados) para la inserción
    cursor.executemany(sql_spotify, df_unicos.values.tolist())
    # Confirma la transacción en la base de datos
    cnx.commit() 
    print(f"✅ ÉXITO: Se insertaron {cursor.rowcount} filas únicas en la tabla 'spotify'.")
except Exception as e:
    # En caso de que ocurra otro error durante la inserción
    print(f"❌ ERROR durante la inserción final: {e}")
    # Deshace cualquier cambio si la inserción falla
    cnx.rollback()
# Out:
# --- 🛑 ATENCIÓN: IDs de canciones repetidas descartadas ---
# Se encontraron y descartaron 61 IDs duplicadas:
# ❌ ID: 1Ogp6LEB5Qw1kl0pmpRJwo
# ❌ ID: 5QhyZb93AHFlpznADf9Jsu
# ❌ ID: 7xvqadKFlrEn3WBdx60FP5
# ❌ ID: 3gkaxVLKhjpaLiUzGjuSbH
# ❌ ID: 1jfsYYqVRVdyrbfqwOGdpq
# ❌ ID: 3GJGMPUXISaQdAAOr7OAm9
# ❌ ID: 5f4B9bJra0XLDcDRkcYsEK
# ❌ ID: 2f67tCczV1DxwjsiKhm3wz
# ❌ ID: 525eXAknaCIBpoxHGHrjwt
# ❌ ID: 14OWTW3gB3UPDhz0J1lcak
# ❌ ID: 5oa1hcdOT426gWWZ6ZKPru
# ❌ ID: 3vVWk5It0E9siRKKn0RInw
# ❌ ID: 4isDdT0nFh0VXhCTVEEISD
# ❌ ID: 4qkVb2zemrcfAiHLH2Jc7L
# ❌ ID: 6g4y38jrL9AqPW7dXVSe8p
# ❌ ID: 3eLrmO04uxtZPgjL846qbb
# ❌ ID: 1oc22PLiDwmVKudDNGBTUk
# ❌ ID: 7xqR92Kowv1VIsiUbJ6t3P
# ❌ ID: 4ZCU5XdO7HWshWRlWKg5Yf
# ❌ ID: 3HwnmR5Elvm3aHRRYiz4kr
# ❌ ID: 0Wu2aurcMw6theY4nQgLPp
# ❌ ID: 2d1CRXLd1DJHeHFQPG0lF7
# ❌ ID: 1JbTZIZcEZRGM7J2OyF3ZJ
# ❌ ID: 7q8FFLCmQ8j9EhtoKyqtx2
# ❌ ID: 6RqpYSSE8g57EJzEl05al7
# ❌ ID: 7iBEzm2Pt90mjqWTjQBkfG
# ❌ ID: 72QBBuwggcOGz0lVmajzfp
# ❌ ID: 1Xjt165Bwl3DJxuvraFWSL
# ❌ ID: 65ldmXqHh3sbz2Kbrgg81A
# ❌ ID: 2rIJInYqXxLtBsr4tv4iVI
# ❌ ID: 0zWFmIgB6s2bpCB8wj7tFU
# ❌ ID: 5TDcq4xiAFoohjEzB83dKc
# ❌ ID: 499T7X9VKIT7M71Q2JKqPR
# ❌ ID: 0SI8x9Coe0xCMvZUq5Bszg
# ❌ ID: 39nDyECADRGyIzUhuflKB5
# ❌ ID: 42CxIkeUuAFpLVOz8DLi71
# ❌ ID: 1Ei0rkpxztRumGySFqLdfo
# ❌ ID: 6cQoQFxTIB89DVrLhFxQBQ
# ❌ ID: 1e1McL6hjKveUWLpy03qUH
# ❌ ID: 2Jia7LolY0bRVsgBRpBpG9
# ❌ ID: 1MZ2PVbZHXA5fIPR96o79f
# ❌ ID: 6Acl5CFe4dbjG0H2xiC0xB
# ❌ ID: 0cL9B4rd7T6eZvUvypSP6f
# ❌ ID: 4URmdc4wJ9IlzVk6Kb5T6R
# ❌ ID: 03dBiBUSOTKiiOsRp6kdNm
# ❌ ID: 3cEoEsV8VYuocogAsU1WpH
# ❌ ID: 7zdKIzgk3CrxzEeF268Vii
# ❌ ID: 6A0vd0vOuJDczvbwtN9oIZ
# ❌ ID: 4uwrECHi5yga5Au4vkRhZK
# ❌ ID: 4FLwlKPYQ1fqxD3Edd6hMs
# ❌ ID: 2URASsTdMZN1BQ0UnNTQHx
# ❌ ID: 1WIqDDnC3nrdPrV4xwPB4y
# ❌ ID: 3HzWalmFCItcZ7SUsddbzN
# ❌ ID: 6r53EJbzzzC2HGIHOmuNve
# ❌ ID: 52uiceQetkHJYkaa8hEZMu
# ❌ ID: 4lIh1ohrRufZ17wN5WTZMH
# ❌ ID: 5epJh0RcVEMC4qxsJIikbZ
# ❌ ID: 1fJlgVMwbx8gvegNeg2Yw9
# ❌ ID: 68gzf3AleOyt4NlKwpV0MY
# ❌ ID: 11RIJRbBfyLlJut96itSFd
# ❌ ID: 3XCG6g2qjsbSWZbGiPONod
# ----------------------------------------------------------
# Datos a insertar: 2939 filas únicas.
# ✅ ÉXITO: Se insertaron 2939 filas únicas en la tabla 'spotify'.

# %%
cnx.close()
